# %%
import os
print(os.getcwd())

# %%
# loading data
import pandas as pd
kpss = pd.read_csv("../data/KPSS_2024.csv")
cpc = pd.read_csv("../data/Match_patent_cpc_2024.csv")
sim = pd.read_csv("../data/PatentSimilarityImportanceBreakthrough_forPost2022.csv")
patent = pd.read_csv("../data/g_patent.tsv", sep="\t")
merged_data = pd.read_csv("../data/merged_patent_data.csv")

# %%
merged_data.head(20)
